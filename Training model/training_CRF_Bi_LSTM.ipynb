# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c41c5449-e870-47a9-8f84-aa948b1a15d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c41c5449-e870-47a9-8f84-aa948b1a15d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-abf57e17-740f-4b96-bd29-9094869224f0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-abf57e17-740f-4b96-bd29-9094869224f0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#!pip install torch torchcrf

# %%
#!pip install torchcrf

# %%
#!pip install dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the CSV file that you previously saved
result_df = pd.read_csv('NER_iob.csv')

# Count the occurrences of each entity type
entity_counts = result_df['Entity_Type_Number'].value_counts()

# Exclude '0' entity (entities with no type)
entity_counts = entity_counts[entity_counts.index != 0]

# Plot the filtered entity counts
entity_counts.plot(kind='bar', figsize=(10, 6))

# Add plot details
plt.title('Entity Distribution')
plt.xlabel('Entity Type Number')
plt.ylabel('Count')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Re-map entity numbers back to names
entity_type_mapping = {
    1: 'Cable Assemblies',
    2: 'Control Systems',
    3: 'Connectors',
    4: 'Wireless',
    5: 'Electromechanical',
    6: 'Sensors',
    7: 'Drone',
    8: 'Electronic Components',
    9: 'Raspberry Pi',
    10: 'Development Boards',
    11: 'Device',
    12: 'Networking',
    13: 'Actuator',
    14: 'Environmental Monitoring',
    15: 'Protocols',
    16: 'Storage Components',
    17: 'HAT'
}

# Read the CSV file (assuming 'result_df' already exists)
result_df = pd.read_csv('NER_iob.csv')

# Map entity numbers back to their names
result_df['Entity_Type_Name'] = result_df['Entity_Type_Number'].map(entity_type_mapping)

# Count occurrences of each entity type by name
entity_counts = result_df['Entity_Type_Name'].value_counts()

# Exclude '0' entity (no entity type)
entity_counts = entity_counts[entity_counts.index != '0']

# Define custom colors based on percentage range
colors = []
for count in entity_counts:
    percentage = (count / sum(entity_counts)) * 100
    if percentage < 5:
        colors.append('red')   # Less than 5%
    elif 5 <= percentage < 10:
        colors.append('orange') # Between 5% and 10%
    elif 10 <= percentage < 15:
        colors.append('yellow') # Between 10% and 15%
    else:
        colors.append('pink')  # Greater than 15%

# Plot the pie chart with custom colors and entity names
plt.figure(figsize=(7, 7))
plt.pie(entity_counts, labels=entity_counts.index, colors=colors, autopct='%1.1f%%')
plt.title('Entity Type Distribution')
# Create a legend explaining the colors
legend_labels = [
    'Less than 5% (red)',
    '5% to 10% (orange)',
    '10% to 15% (yellow)',
    'Greater than 15% (pink)'
]

# Add the legend to the plot
plt.legend(legend_labels, loc="upper right", title="Percentage Range")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# Re-map entity numbers back to names
entity_type_mapping = {
    1: 'Cable Assemblies',
    2: 'Control Systems',
    3: 'Connectors',
    4: 'Wireless',
    5: 'Electromechanical',
    6: 'Sensors',
    7: 'Drone',
    8: 'Electronic Components',
    9: 'Raspberry Pi',
    10: 'Development Boards',
    11: 'Device',
    12: 'Networking',
    13: 'Actuator',
    14: 'Environmental Monitoring',
    15: 'Protocols',
    16: 'Storage Components',
    17: 'HAT'
}
# Read the CSV file (assuming 'result_df' already exists)
filtered_df = pd.read_csv('NER_iob.csv')

# Map Entity_Type_Number to Entity_Type_Name using the entity_type_mapping dictionary
filtered_df['Entity_Type_Name'] = filtered_df['Entity_Type_Number'].map(entity_type_mapping)

# Create a bar plot for Entity_Type_Name frequencies (after removing 0)
plt.figure(figsize=(10, 6))
sns.countplot(data=filtered_df, x='Entity_Type_Name', palette='Set2')
plt.title('Frequency of IoT Entity Types (Excluding Non-entities)')
plt.xlabel('Entity Type Name')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate labels for better readability
plt.show()
# Out:
# <ipython-input-2-5eecf34f778d>:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=filtered_df, x='Entity_Type_Name', palette='Set2')
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
# Create a bar plot for IOB tag frequencies
plt.figure(figsize=(10, 6))
sns.countplot(data=result_df, x='IOB', palette='Set3')
plt.title('Frequency of IOB Tags')
plt.xlabel('IOB Tags')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-7-5c557c85bdb1>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=result_df, x='IOB', palette='Set3')
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
# Get the frequency of each token
token_counts = result_df['Token'].value_counts().nlargest(20)  # Show top 20 tokens

# Create a bar plot for Token frequency
plt.figure(figsize=(12, 8))
sns.barplot(x=token_counts.values, y=token_counts.index, palette='Blues_r')
plt.title('Top 20 Most Frequent Tokens')
plt.xlabel('Frequency')
plt.ylabel('Token')
plt.show()
# Out:
# <ipython-input-8-de90546ddd5f>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=token_counts.values, y=token_counts.index, palette='Blues_r')
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
# Filter out rows where Entity_Type_Number is 0
filtered_df = result_df[result_df['Entity_Type_Number'] != 0]

# Create a grouped bar plot for IOB tags per Entity Type
plt.figure(figsize=(12, 6))
sns.countplot(data=filtered_df, x='Entity_Type_Number', hue='IOB', palette='pastel')
plt.title('IOB Tag Distribution by Entity Type (Excluding Non-entities)')
plt.xlabel('Entity Type Number')
plt.ylabel('Count')
plt.legend(title='IOB Tag')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
# Define the entity type mapping
entity_type_mapping = {
    1: 'Cable Assemblies',
    2: 'Control Systems',
    3: 'Connectors',
    4: 'Wireless',
    5: 'Electromechanical',
    6: 'Sensors',
    7: 'Drone',
    8: 'Electronic Components',
    9: 'Raspberry Pi',
    10: 'Development Boards',
    11: 'Device',
    12: 'Networking',
    13: 'Actuator',
    14: 'Environmental Monitoring',
    15: 'Protocols',
    16: 'Storage Components',
    17: 'HAT'
}

# Replace Entity_Type_Number with corresponding names
result_df['Entity_Type_Name'] = result_df['Entity_Type_Number'].replace(entity_type_mapping)

# Filter out rows where Entity_Type_Number is 0
filtered_df = result_df[result_df['Entity_Type_Number'] != 0]

# Create a grouped bar plot for IOB tags per Entity Type using the new names
plt.figure(figsize=(12, 6))
sns.countplot(data=filtered_df, x='Entity_Type_Name', hue='IOB', palette='pastel')
plt.title('IOB Tag Distribution by Entity Type (Excluding Non-entities)')
plt.xlabel('Entity Type')
plt.ylabel('Count')
plt.legend(title='IOB Tag')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('NER_iob.csv')

# Count occurrences of each IOB label
iob_counts = df['IOB'].value_counts()

# Display the counts for I, O, B
print("Count of each IOB tag:")
print(iob_counts)
# Out:
# Count of each IOB tag:
# IOB
# O    10180
# B      576
# I      560
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Plot the distribution of IOB tags
plt.figure(figsize=(8, 6))
iob_counts.plot(kind='bar', color=['skyblue', 'orange', 'green'])

# Add title and labels
plt.title('Distribution of IOB Tags in Dataset', fontsize=16)
plt.xlabel('IOB Tags', fontsize=14)
plt.ylabel('Count', fontsize=14)

# Add grid and show the plot
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=0)  # Keep the x-axis labels horizontal
plt.show()

# %% [markdown]
# As you can see, the 'O' tag is the most common, followed by 'B' and 'I'. This clearly highlights the imbalance in your dataset, which is a common challenge in NER tasks.

# %%
# import all the necessery library that i will need
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, f1_score, precision_score, recall_score, precision_recall_fscore_support
import torch

# %% [markdown]
# -> so will need to capture the hidden states from the Bi-LSTM layer to visualize attention over the tokens in the  Bi-LSTM Model to Return Hidden States and to return hidden states along with logits

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
from sklearn.utils.class_weight import compute_class_weight
from torch.nn.utils.rnn import pad_sequence
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('Ner.csv')

# Map IOB to numerical values
iob_mapping = {'O': 0, 'B': 1, 'I': 2}
df['IOB'] = df['IOB'].map(iob_mapping)

# Calculate class weights based on IOB distribution
class_weights = compute_class_weight('balanced', classes=np.array([0, 1, 2]), y=df['IOB'])
class_weights = torch.tensor(class_weights, dtype=torch.float)

# Prepare tokens, IOB tags, and attention masks
tokens = df['Token'].tolist()
iob_tags = df['IOB'].tolist()
attention_masks = df['Attention_Mask'].tolist()

# Create a mapping for unique tokens to IDs
token_to_id = {token: idx for idx, token in enumerate(set(tokens))}
token_ids = [token_to_id[token] for token in tokens]

# Create Dataset class
class NERDataset(Dataset):
    def __init__(self, tokens, tags, attention_masks):
        self.tokens = tokens
        self.tags = tags
        self.attention_masks = attention_masks

    def __len__(self):
        return len(self.tokens)

    def __getitem__(self, idx):
        return {
            'tokens': torch.tensor(self.tokens[idx], dtype=torch.long),
            'tags': torch.tensor(self.tags[idx], dtype=torch.long),
            'attention_mask': torch.tensor(self.attention_masks[idx], dtype=torch.long)
        }

# Split the dataset into training and validation sets
train_data, val_data, train_tags, val_tags, train_masks, val_masks = train_test_split(
    token_ids, iob_tags, attention_masks, test_size=0.2, random_state=42)

# Create datasets for both training and validation
train_dataset = NERDataset([train_data], [train_tags], [train_masks])
val_dataset = NERDataset([val_data], [val_tags], [val_masks])

# Create data loaders
train_dataloader = DataLoader(train_dataset, batch_size=2, shuffle=True,
                              collate_fn=lambda x: {
                                  'tokens': pad_sequence([item['tokens'] for item in x], batch_first=True),
                                  'tags': pad_sequence([item['tags'] for item in x], batch_first=True),
                                  'attention_mask': pad_sequence([item['attention_mask'] for item in x], batch_first=True)
                              })

val_dataloader = DataLoader(val_dataset, batch_size=2, shuffle=False,
                            collate_fn=lambda x: {
                                'tokens': pad_sequence([item['tokens'] for item in x], batch_first=True),
                                'tags': pad_sequence([item['tags'] for item in x], batch_first=True),
                                'attention_mask': pad_sequence([item['attention_mask'] for item in x], batch_first=True)
                            })

# Define your Bi-LSTM + CRF model
class BiLSTM_CRF(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, num_classes):
        super(BiLSTM_CRF, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, bidirectional=True, batch_first=True)
        self.fc = nn.Linear(hidden_dim * 2, num_classes)  # *2 for bidirectional

    def forward(self, tokens, attention_mask):
        # Get embeddings
        embedded = self.embedding(tokens)

        # Pass through LSTM
        lstm_out, _ = self.lstm(embedded)

        # Apply dropout to LSTM output
        lstm_out = F.dropout(lstm_out, p=0.5, training=self.training)

        # Pass through the fully connected layer
        logits = self.fc(lstm_out)

        # Return the logits which will be used for loss calculation
        return logits

# Model parameters
num_classes = len(iob_mapping)
vocab_size = len(token_to_id)  # Size of vocabulary
embedding_dim = 100  # Set your embedding dimension
hidden_dim = 64      # Set your hidden layer size

# Initialize model with L2 regularization and optimizer with weight decay
model = BiLSTM_CRF(vocab_size, embedding_dim, hidden_dim, num_classes)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
loss_function = nn.CrossEntropyLoss(weight=class_weights)

# Lists to store the summary of each epoch for both training and validation
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []
results = pd.DataFrame(columns=["Epoch", "Train Loss", "Train Accuracy", "Val Loss", "Val Accuracy",
                                 "Val Precision", "Val Recall", "Val F1-Score"])

# Early stopping parameters
best_val_loss = float('inf')
patience_counter = 0
patience_limit = 10

# Training loop
num_epochs = 200

for epoch in range(num_epochs):
    model.train()
    total_train_loss = 0

    for batch in train_dataloader:
        optimizer.zero_grad()

        tokens = batch['tokens']
        tags = batch['tags']
        attention_mask = batch['attention_mask']

        # Forward pass
        outputs = model(tokens, attention_mask)

        # Compute loss and adjust for padding
        loss = loss_function(outputs.view(-1, num_classes), tags.view(-1))

        total_train_loss += loss.item()

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

    avg_train_loss = total_train_loss / len(train_dataloader)
    train_losses.append(avg_train_loss)

    # Evaluation on training set (for training accuracy)
    model.eval()
    train_predictions = []
    train_true_labels = []

    with torch.no_grad():
        for batch in train_dataloader:
            tokens = batch['tokens']
            tags = batch['tags']
            attention_mask = batch['attention_mask']

            # Forward pass
            outputs = model(tokens, attention_mask)
            predicted_tags = outputs.argmax(dim=2)  # Get predicted tags for each token

            # Collect predictions and true labels
            train_predictions.extend(predicted_tags.view(-1).cpu().numpy())
            train_true_labels.extend(tags.view(-1).cpu().numpy())

    # Calculate training accuracy
    train_accuracy = accuracy_score(train_true_labels, train_predictions)
    train_accuracies.append(train_accuracy)

    # Validation loop
    total_val_loss = 0
    val_predictions = []
    val_true_labels = []

    with torch.no_grad():
        for batch in val_dataloader:
            tokens = batch['tokens']
            tags = batch['tags']
            attention_mask = batch['attention_mask']

            # Forward pass
            outputs = model(tokens, attention_mask)

            # Compute validation loss
            loss = loss_function(outputs.view(-1, num_classes), tags.view(-1))
            total_val_loss += loss.item()

            # Get validation predictions
            predicted_tags = outputs.argmax(dim=2)
            val_predictions.extend(predicted_tags.view(-1).cpu().numpy())
            val_true_labels.extend(tags.view(-1).cpu().numpy())

    avg_val_loss = total_val_loss / len(val_dataloader)
    val_losses.append(avg_val_loss)

    val_accuracy = accuracy_score(val_true_labels, val_predictions)
    val_accuracies.append(val_accuracy)

    # Print metrics for this epoch
    print(f"Epoch {epoch + 1}/{num_epochs}, "
          f"Train Loss: {avg_train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, "
          f"Val Loss: {avg_val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}")

    # Generate F1 Score metrics for validation set
    val_precision = precision_score(val_true_labels, val_predictions, average='macro', zero_division=0)
    val_recall = recall_score(val_true_labels, val_predictions, average='macro', zero_division=0)
    val_f1_score = f1_score(val_true_labels, val_predictions, average='macro', zero_division=0)

    print(f"Validation Precision: {val_precision:.4f}, Validation Recall: {val_recall:.4f}, Validation F1-Score: {val_f1_score:.4f}")

    results.loc[len(results)] = [epoch + 1,
                                  avg_train_loss,
                                  train_accuracy,
                                  avg_val_loss,
                                  val_accuracy,
                                  val_precision,
                                  val_recall,
                                  val_f1_score]

    # Early stopping check
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        patience_counter = 0
    else:
        patience_counter += 1

    if patience_counter >= patience_limit:
        print("Early stopping triggered.")
        break

# Save the result table to a CSV file
results.to_csv('CRFresults.csv', index=False)

# Plotting the training and validation loss and accuracy
plt.figure(figsize=(12, 5))

# Plot Training and Validation Loss
plt.subplot(1, 2, 1)
plt.plot(range(1,len(train_losses)+1), train_losses,label='Train Loss')
plt.plot(range(1,len(val_losses)+1), val_losses,label='Val Loss', color='orange')
plt.title('Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()

# Plot Training and Validation Accuracy
plt.subplot(1, 2, 2)
plt.plot(range(1,len(train_accuracies)+1), train_accuracies,label='Train Accuracy')
plt.plot(range(1,len(val_accuracies)+1), val_accuracies,label='Val Accuracy', color='orange')
plt.title('Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/200, Train Loss: 1.1117, Train Accuracy: 0.2907, Val Loss: 1.0864, Val Accuracy: 0.2967
# Validation Precision: 0.3457, Validation Recall: 0.4077, Validation F1-Score: 0.2036
# Epoch 2/200, Train Loss: 1.0976, Train Accuracy: 0.3805, Val Loss: 1.0761, Val Accuracy: 0.3835
# Validation Precision: 0.3566, Validation Recall: 0.4516, Validation F1-Score: 0.2475
# Epoch 3/200, Train Loss: 1.0793, Train Accuracy: 0.4320, Val Loss: 1.0662, Val Accuracy: 0.4407
# Validation Precision: 0.3646, Validation Recall: 0.4910, Validation F1-Score: 0.2775
# Epoch 4/200, Train Loss: 1.0685, Train Accuracy: 0.4769, Val Loss: 1.0566, Val Accuracy: 0.4928
# Validation Precision: 0.3734, Validation Recall: 0.5388, Validation F1-Score: 0.3074
# Epoch 5/200, Train Loss: 1.0597, Train Accuracy: 0.5231, Val Loss: 1.0472, Val Accuracy: 0.5402
# Validation Precision: 0.3834, Validation Recall: 0.5826, Validation F1-Score: 0.3358
# ...

# %% [markdown]
# **So we try to train a model with 30 epochs and see the result and performance metrics**
#
#
# *   Evaluate the previous part of code that combine between CRF and Bi-LSTM to have a good result and good metric

# %% [markdown]
# -> training a Named Entity Recognition (NER) model using a Bi-directional Long Short-Term Memory (BiLSTM) network with a Conditional Random Field (CRF) layer.
#
# Explain some code here
# *   nn: Contains various neural network components.
# *   F: Contains functional operations for neural networks.
# *   Maps unique tokens to integer IDs and converts the token list into a list of token IDs using the mapping.

# %% [markdown]
# -> In the next step i try to Train a model with pre-trained model to see the difference and do teh benchmark between pre-trained model and model that create from scratch

# %%
### Correct code for CRF and Bi-LSTM
from transformers import Trainer, TrainingArguments, BertTokenizerFast, BertForTokenClassification, DataCollatorForTokenClassification


# Load the dataset
df = pd.read_csv('Nerdata.csv')

# Map IOB to numerical values
iob_mapping = {'O': 0, 'B': 1, 'I': 2}
df['IOB'] = df['IOB'].map(iob_mapping)

# Create a 'Sentence_ID' column assuming each sentence ends with a period (.)
df['Sentence_ID'] = (df['Token'] == '.').cumsum()

# Split the dataset
train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)

# Load the BERT tokenizer
tokenizer = BertTokenizerFast.from_pretrained('bert-base-uncased')

# Function to tokenize input and align labels
def tokenize_and_align_labels(grouped_sentences):
    tokenized_inputs = tokenizer(
        grouped_sentences['Token'].tolist(),
        is_split_into_words=True,
        padding=True,
        truncation=True,
        return_tensors="pt"
    )

    labels = []
    word_ids = tokenized_inputs.word_ids(batch_index=0)

    current_labels = grouped_sentences['IOB'].tolist()
    label_ids = []
    previous_word_idx = None

    for word_idx in word_ids:
        if word_idx is None:
            label_ids.append(-100)  # Ignored for special tokens
        elif word_idx != previous_word_idx:
            label_ids.append(current_labels[word_idx])  # Use label for the first subword
        else:
            label_ids.append(-100)  # Ignore subsequent subwords

        previous_word_idx = word_idx

    tokenized_inputs['labels'] = torch.tensor(label_ids, dtype=torch.long)
    return tokenized_inputs

# Group data by sentences
train_grouped = train_data.groupby("Sentence_ID")
test_grouped = test_data.groupby("Sentence_ID")

# Tokenize and align labels for the training and test sets
def process_grouped_data(grouped_data):
    tokenized_data = []
    for _, group in grouped_data:
        tokenized_inputs = tokenize_and_align_labels(group)
        tokenized_data.append(tokenized_inputs)
    return tokenized_data

train_encodings = process_grouped_data(train_grouped)
test_encodings = process_grouped_data(test_grouped)

# Create Dataset for Trainer
class NERDataset(torch.utils.data.Dataset):
    def __init__(self, encodings):
        self.encodings = encodings

    def __getitem__(self, idx):
        return {key: self.encodings[idx][key].squeeze(0) for key in self.encodings[idx]}

    def __len__(self):
        return len(self.encodings)

train_dataset = NERDataset(train_encodings)
eval_dataset = NERDataset(test_encodings)

# Load the BERT model
model = BertForTokenClassification.from_pretrained('bert-base-uncased', num_labels=len(iob_mapping))

# Define a data collator for dynamic padding
data_collator = DataCollatorForTokenClassification(tokenizer)

# Set up training arguments
training_args = TrainingArguments(
    output_dir='./BERTtest',
    num_train_epochs=30,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    logging_dir='./runs',  # Directory for storing logs
    logging_steps=10,  # Log every 10 steps
    evaluation_strategy="epoch",  # Evaluate at the end of each epoch
    save_strategy="epoch",
    load_best_model_at_end=True,
    save_steps=1000,
    save_total_limit=2
)

# Define metrics computation
def compute_metrics(pred):
    predictions, labels = pred
    predictions = np.argmax(predictions, axis=2)
    true_labels = labels

    # Flatten the predictions and labels
    true_labels_flat = true_labels.flatten()
    predictions_flat = predictions.flatten()

    # Filter out -100 (ignored tokens) from the evaluation
    mask = true_labels_flat != -100
    true_labels_flat = true_labels_flat[mask]
    predictions_flat = predictions_flat[mask]

    # Calculate metrics
    accuracy = accuracy_score(true_labels_flat, predictions_flat)
    precision, recall, f1, _ = precision_recall_fscore_support(true_labels_flat, predictions_flat, average='weighted')

    return {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1': f1
    }

# Initialize the Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    data_collator=data_collator,  # Add the data collator for dynamic padding
    compute_metrics=compute_metrics
)

# Train the model
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# ...

# %%
import matplotlib.pyplot as plt

# Extract training history from the trainer's state log
log_history = trainer.state.log_history

# Initialize lists to store loss and accuracy values
train_loss = []
eval_loss = []
eval_accuracy = []
steps = []

# Parse log history to get the relevant metrics
for log in log_history:
    if 'loss' in log:
        train_loss.append(log['loss'])
        steps.append(log['step'])
    if 'eval_loss' in log:
        eval_loss.append(log['eval_loss'])
    if 'eval_accuracy' in log:
        eval_accuracy.append(log['eval_accuracy'])

# Plotting the curves
plt.figure(figsize=(12, 6))

# Plot the training loss
plt.subplot(1, 2, 1)
plt.plot(steps, train_loss, label="Training Loss", color='blue')
plt.plot(steps[:len(eval_loss)], eval_loss, label="Validation Loss", color='red')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# Plot the evaluation accuracy
plt.subplot(1, 2, 2)
plt.plot(steps[:len(eval_accuracy)], eval_accuracy, label="Validation Accuracy", color='green')
plt.xlabel('Steps')
plt.ylabel('Accuracy')
plt.title('Validation Accuracy')
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

def plot_training_metrics(trainer):
    # Extract log history from the trainer
    history = trainer.state.log_history

    # Initialize lists to store metrics
    epochs = []
    train_losses = []
    eval_accuracies = []

    # Loop through the log history and extract relevant data
    for log in history:
        if 'loss' in log:
            train_losses.append(log['loss'])
            epochs.append(log['epoch'])
        if 'eval_accuracy' in log:
            eval_accuracies.append(log['eval_accuracy'])

    # Convert epochs to a list of indices for evaluation accuracy
    eval_epochs = [log['epoch'] for log in history if 'eval_accuracy' in log]

    # Plot training loss over epochs
    plt.figure(figsize=(12, 5))

    # Plot Loss curve
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label="Training Loss", color='blue')
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Bert Training Loss Curve")
    plt.legend()

    # Plot Accuracy curve
    plt.subplot(1, 2, 2)
    plt.plot(eval_epochs, eval_accuracies, label="Evaluation Accuracy", color='orange')
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.title("Bert Evaluation Accuracy Curve")
    plt.legend()

    # Show the plots
    plt.tight_layout()
    plt.show()

# Call the function to plot the metrics
plot_training_metrics(trainer)

# %%
import matplotlib.pyplot as plt

# After training, log history will contain training and evaluation metrics
log_history = trainer.state.log_history

# Initialize lists to store epoch numbers, training loss, and evaluation loss
epochs_train = []
train_loss = []
epochs_eval = []
eval_loss = []

# Loop through log history and extract training/evaluation loss at each epoch
for log in log_history:
    if 'loss' in log.keys() and 'epoch' in log.keys():
        train_loss.append(log['loss'])
        epochs_train.append(log['epoch'])
    if 'eval_loss' in log.keys() and 'epoch' in log.keys():
        eval_loss.append(log['eval_loss'])
        epochs_eval.append(log['epoch'])

# Plot training and validation loss curves
plt.figure(figsize=(10, 6))

# Plot training loss
plt.plot(epochs_train, train_loss, label='Training Loss', marker='o', linestyle='-')

# Plot validation loss
plt.plot(epochs_eval, eval_loss, label='Validation Loss', marker='x', linestyle='--')

plt.title("Deep Learning Training Curve: Training & Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid()
plt.show()
# Plot Evaluation Accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs_eval, eval_accuracy, label='Evaluation Accuracy', marker='x', linestyle='--')
plt.title('Bert Evaluation Accuracy vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, f1_score, precision_score, recall_score
from sklearn.preprocessing import label_binarize

# Assuming you have val_true_labels and val_predictions from your validation loop
# Convert true labels and predictions to binary format for ROC calculation
num_classes = len(iob_mapping)  # Number of classes (0, 1, 2 for O, B, I)
y_true_bin = label_binarize(val_true_labels, classes=[0, 1, 2])
y_pred_bin = label_binarize(val_predictions, classes=[0, 1, 2])

# Calculate F1 Score
f1_scores = []
for i in range(num_classes):
    f1 = f1_score(y_true_bin[:, i], y_pred_bin[:, i])
    f1_scores.append(f1)

print(f"F1 Scores for each class: {f1_scores}")

# Calculate ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_bin[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plotting the ROC curves
plt.figure(figsize=(12, 8))
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f'ROC curve of class {i} (area = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# Plotting training metrics as before
def plot_training_metrics(trainer):
    # Extract log history from the trainer
    history = trainer.state.log_history

    # Initialize lists to store metrics
    epochs = []
    train_losses = []
    eval_accuracies = []

    # Loop through the log history and extract relevant data
    for log in history:
        if 'loss' in log:
            train_losses.append(log['loss'])
            epochs.append(log['epoch'])
        if 'eval_accuracy' in log:
            eval_accuracies.append(log['eval_accuracy'])

    # Convert epochs to a list of indices for evaluation accuracy
    eval_epochs = [log['epoch'] for log in history if 'eval_accuracy' in log]

    # Plot training loss over epochs
    plt.figure(figsize=(12, 5))

    # Plot Loss curve
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label="Training Loss", color='blue')
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Bert Training Loss Curve")
    plt.legend()

    # Plot Accuracy curve
    plt.subplot(1, 2, 2)
    plt.plot(eval_epochs, eval_accuracies, label="Evaluation Accuracy", color='orange')
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.title("Bert Evaluation Accuracy Curve")
    plt.legend()

    # Show the plots
    plt.tight_layout()
    plt.show()

# Call the function to plot the metrics
plot_training_metrics(trainer)
# Out:
# F1 Scores for each class: [0.9289405684754521, 0.4419889502762431, 0.2541436464088398]

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# *Example of test the model if can give me a good result or not to take a conclusio in the end*

# %%
import pandas as pd
from transformers import BertTokenizer, BertForTokenClassification
import torch

# Load your dataset
df = pd.read_csv('melted_data.csv')

# Extract the 'Component' column and drop NaN values
new_tokens = df['Component'].dropna().unique()  # Get unique components

# Clean tokens if necessary (e.g., replacing spaces with underscores)
new_tokens = [token.replace(" ", "_") for token in new_tokens if isinstance(token, str)]  # Ensure token is a string

# Load the pre-trained BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Add new tokens (components) to the tokenizer
num_added_tokens = tokenizer.add_tokens(new_tokens)
print(f"Added {num_added_tokens} new tokens to the tokenizer.")

# Load the pre-trained BERT model and resize token embeddings
model = BertForTokenClassification.from_pretrained('/content/BERTtest/checkpoint-56')  # Load from directory
model.resize_token_embeddings(len(tokenizer))

# Set the model to evaluation mode
model.eval()

# Define a function to tokenize input and make predictions
def predict(text, model, tokenizer):
    # Tokenize the input text
    encoding = tokenizer(
        text.split(),
        is_split_into_words=True,
        padding=True,
        truncation=True,
        return_tensors="pt"
    )

    input_ids = encoding['input_ids'].to(model.device)
    attention_mask = encoding['attention_mask'].to(model.device)

    # Make predictions
    with torch.no_grad():
        outputs = model(input_ids, attention_mask=attention_mask)
        logits = outputs.logits

    # Convert logits to predictions
    predictions = torch.argmax(logits, dim=-1)

    # Convert predictions to labels
    id2label = model.config.id2label  # Use id2label from model config
    predicted_labels = [id2label[label.item()] for label in predictions[0]]

    # Decode tokens from token IDs
    tokens = tokenizer.convert_ids_to_tokens(input_ids[0].tolist())

    # Combine tokens with their predicted labels
    results = list(zip(tokens, predicted_labels))

    return results

# Read text from file
with open('test data.txt', 'r') as file:  # Update the file path
    text = file.read()

def post_process_predictions(results):
    corrected_results = []
    for i in range(len(results)):
        token, label = results[i]
        if i > 0:  # Check previous token
            prev_token, prev_label = results[i - 1]
            if label == 'LABEL_0' and prev_label == 'LABEL_1':  # Example condition
                label = 'LABEL_1'  # Correct to the appropriate label
        corrected_results.append((token, label))
    return corrected_results

# Use post-processing on predicted results
corrected_results = post_process_predictions(predicted_results)

# Print results in a readable format
for token, label in corrected_results:
    print(f"{token}: {label}")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Added 1115 new tokens to the tokenizer.
# [CLS]: LABEL_0
# in: LABEL_0
# a: LABEL_0
# smart: LABEL_0
# agriculture: LABEL_0
# system: LABEL_0
# ,: LABEL_0
# soil: LABEL_1
# moisture: LABEL_2
# sensors: LABEL_2
# and: LABEL_0
# ph: LABEL_0
# sensors: LABEL_2
# are: LABEL_0
# deployed: LABEL_0
# to: LABEL_0
# monitor: LABEL_0
# soil: LABEL_0
# conditions: LABEL_0
# .: LABEL_0
# the: LABEL_0
# data: LABEL_0
# is: LABEL_0
# transmitted: LABEL_0
# via: LABEL_0
# zigbee: LABEL_0
# protocol: LABEL_0
# to: LABEL_0
# a: LABEL_0
# central: LABEL_0
# monitoring: LABEL_0
# station: LABEL_0
# .: LABEL_0
# ...

# %%
# # Save to a specific folder in your Google Drive
# model.save_pretrained('/content/drive/MyDrive/model/saved_BERTmodel')
# tokenizer.save_pretrained('/content/drive/MyDrive/model/saved_BERTmodel')
